# %% [markdown]
# <a href="https://colab.research.google.com/github/lu7kin/New-world/blob/main/VGG16.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
from tensorflow import keras
from google.colab import files
from io import BytesIO
from PIL import Image

# %%
model = keras.applications.VGG16()
# Out:
# ...
# 553476096/553467096 [==============================] - 3s 0us/step

# %%
uploaded = files.upload()
# Out:
#      <input type="file" id="files-c05bdf4a-ce4b-4e10-8fc0-b13859c37861" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-c05bdf4a-ce4b-4e10-8fc0-b13859c37861">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving 800px-F-117_Nighthawk_Front1.jpg to 800px-F-117_Nighthawk_Front1.jpg

# %%
img = Image.open(BytesIO(uploaded['800px-F-117_Nighthawk_Front1.jpg']))
plt.imshow( img )

# %%
img = np.array(img)
x = keras.applications.vgg16.preprocess_input(img)
print(x.shape)
x = np.expand_dims(x, axis=0)
print(x.shape)
# Out:
# (224, 224, 3)
# (1, 224, 224, 3)

# %%
res = model.predict( x )
print(np.argmax(res))
# Out:
# 895

# %% [markdown]
#  895: 'warplane, military plane'
