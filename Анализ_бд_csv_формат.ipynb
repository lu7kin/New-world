# %% [markdown]
# <a href="https://colab.research.google.com/github/lu7kin/New-world/blob/main/%D0%90%D0%BD%D0%B0%D0%BB%D0%B8%D0%B7_%D0%B1%D0%B4_csv_%D1%84%D0%BE%D1%80%D0%BC%D0%B0%D1%82.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df=pd.read_csv('/content/archive.zip')

# %% [markdown]
# Загрузка библиотеки и датасета

# %%
df_copy=df.copy()

# %% [markdown]
# Копирование датафрейма

# %%
df.shape
# Out:
# (1259, 27)

# %% [markdown]
# Смотрим количество столбцов и строк

# %%
df.head()
# Out:
#              Timestamp  Age  Gender         Country state self_employed  \
# 0  2014-08-27 11:29:31   37  Female   United States    IL           NaN
# 1  2014-08-27 11:29:37   44       M   United States    IN           NaN
# 2  2014-08-27 11:29:44   32    Male          Canada   NaN           NaN
# 3  2014-08-27 11:29:46   31    Male  United Kingdom   NaN           NaN
# 4  2014-08-27 11:30:22   31    Male   United States    TX           NaN
#
#   family_history treatment work_interfere    no_employees  ...  \
# 0             No       Yes          Often            6-25  ...
# 1             No        No         Rarely  More than 1000  ...
# 2             No        No         Rarely            6-25  ...
# 3            Yes       Yes          Often          26-100  ...
# 4             No        No          Never         100-500  ...
#
#                 leave mental_health_consequence phys_health_consequence  \
# 0       Somewhat easy                        No                      No
# ...

# %% [markdown]
# Смотрим первые 5 строк

# %%
df.tail()
# Out:
#                 Timestamp  Age Gender         Country state self_employed  \
# 1254  2015-09-12 11:17:21   26   male  United Kingdom   NaN            No
# 1255  2015-09-26 01:07:35   32   Male   United States    IL            No
# 1256  2015-11-07 12:36:58   34   male   United States    CA            No
# 1257  2015-11-30 21:25:06   46      f   United States    NC            No
# 1258  2016-02-01 23:04:31   25   Male   United States    IL            No
#
#      family_history treatment work_interfere    no_employees  ...  \
# 1254             No       Yes            NaN          26-100  ...
# 1255            Yes       Yes          Often          26-100  ...
# 1256            Yes       Yes      Sometimes  More than 1000  ...
# 1257             No        No            NaN         100-500  ...
# 1258            Yes       Yes      Sometimes          26-100  ...
#
#                    leave mental_health_consequence phys_health_consequence  \
# ...

# %% [markdown]
# Смотрим последние 5 записей

# %%
df.sample()
# Out:
#                Timestamp  Age Gender    Country state self_employed  \
# 740  2014-08-28 10:54:31   37   male  Australia   NaN            No
#
#     family_history treatment work_interfere no_employees  ...      leave  \
# 740            Yes       Yes      Sometimes       26-100  ...  Very easy
#
#     mental_health_consequence phys_health_consequence     coworkers  \
# 740                        No                      No  Some of them
#
#     supervisor mental_health_interview phys_health_interview  \
# 740        Yes                      No                 Maybe
#
#     mental_vs_physical obs_consequence comments
# 740                Yes             Yes      NaN
#
# [1 rows x 27 columns]

# %% [markdown]
# Случайная запись

# %%
df['Gender'].value_counts()
# Out:
# Male                                              615
# male                                              206
# Female                                            121
# M                                                 116
# female                                             62
# F                                                  38
# m                                                  34
# f                                                  15
# Make                                                4
# Male                                                3
# Woman                                               3
# Cis Male                                            2
# Man                                                 2
# Female (trans)                                      2
# Female                                              2
# Trans woman                                         1
# msle                                                1
# ...

# %% [markdown]
# Смотрим информацию по выбранному столбцу

# %%
df.columns.tolist()
# Out:
# ['Timestamp',
#  'Age',
#  'Gender',
#  'Country',
#  'state',
#  'self_employed',
#  'family_history',
#  'treatment',
#  'work_interfere',
#  'no_employees',
#  'remote_work',
#  'tech_company',
#  'benefits',
#  'care_options',
#  'wellness_program',
#  'seek_help',
#  'anonymity',
#  'leave',
#  'mental_health_consequence',
#  'phys_health_consequence',
#  'coworkers',
#  'supervisor',
#  'mental_health_interview',
#  'phys_health_interview',
#  'mental_vs_physical',
#  'obs_consequence',
#  'comments']

# %% [markdown]
# Список названий столбцов

# %%
df.Gender.unique()
# Out:
# array(['Female', 'M', 'Male', 'male', 'female', 'm', 'Male-ish', 'maile',
#        'Trans-female', 'Cis Female', 'F', 'something kinda male?',
#        'Cis Male', 'Woman', 'f', 'Mal', 'Male (CIS)', 'queer/she/they',
#        'non-binary', 'Femake', 'woman', 'Make', 'Nah', 'All', 'Enby',
#        'fluid', 'Genderqueer', 'Female ', 'Androgyne', 'Agender',
#        'cis-female/femme', 'Guy (-ish) ^_^', 'male leaning androgynous',
#        'Male ', 'Man', 'Trans woman', 'msle', 'Neuter', 'Female (trans)',
#        'queer', 'Female (cis)', 'Mail', 'cis male', 'A little about you',
#        'Malr', 'p', 'femail', 'Cis Man',
#        'ostensibly male, unsure what that really means'], dtype=object)

# %% [markdown]
# Уникальные значения столбца

# %%
df.insert(1,'new_col',300)

# %% [markdown]
# Добавление столбца

# %%
df.drop(['new_col'], axis=1)
# Out:
#                 Timestamp  Age  Gender         Country state self_employed  \
# 0     2014-08-27 11:29:31   37  Female   United States    IL           NaN
# 1     2014-08-27 11:29:37   44       M   United States    IN           NaN
# 2     2014-08-27 11:29:44   32    Male          Canada   NaN           NaN
# 3     2014-08-27 11:29:46   31    Male  United Kingdom   NaN           NaN
# 4     2014-08-27 11:30:22   31    Male   United States    TX           NaN
# ...                   ...  ...     ...             ...   ...           ...
# 1254  2015-09-12 11:17:21   26    male  United Kingdom   NaN            No
# 1255  2015-09-26 01:07:35   32    Male   United States    IL            No
# 1256  2015-11-07 12:36:58   34    male   United States    CA            No
# 1257  2015-11-30 21:25:06   46       f   United States    NC            No
# 1258  2016-02-01 23:04:31   25    Male   United States    IL            No
#
#      family_history treatment work_interfere    no_employees  ...  \
# ...

# %% [markdown]
# Удаление столбца

# %%
my_df=pd.DataFrame([[1,'Irina', '1a'],
                    [2,'Stas','4g'],
                    [3,'Olga','4f']],
                   columns=['id','name','class'])

# %%
my_df
# Out:
#    id   name class
# 0   1  Irina    1a
# 1   2   Stas    4g
# 2   3   Olga    4f

# %% [markdown]
# Создание датасета вручную
